# %% [markdown]
# # LSTM with Keras

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Creating documents with labels

# %%
documents = [
    "Deep learning uses neural networks.",
    "LSTMs are powerful sequence models.",
    "I enjoy studying machine learning.",
    "Deep learning is truly amazing.",
    "Natural language processing is fascinating.",
    "Poorly trained models produce inaccurate results.",
]

# %%
labels = np.array([1, 1, 1, 0, 0, 0])

# %%
documents, labels
# Out:
# (['Deep learning uses neural networks.',
#   'LSTMs are powerful sequence models.',
#   'I enjoy studying machine learning.',
#   'Deep learning is truly amazing.',
#   'Natural language processing is fascinating.',
#   'Poorly trained models produce inaccurate results.'],
#  array([1, 1, 1, 0, 0, 0]))

# %% [markdown]
# ## Initializing TextVectorization

# %%
from tensorflow.keras.layers import TextVectorization

# %%
vectorizer = TextVectorization(
    max_tokens = 15000,
    standardize = 'lower_and_strip_punctuation',
    split = 'whitespace',
    output_mode = 'int',
    output_sequence_length = 8
)

# %%
vectorizer.adapt(documents)

# %%
encoded = vectorizer(documents)

# %% [markdown]
# ## Creating a LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()

model.add(
    Embedding(
        input_dim = len(vectorizer.get_vocabulary()) + 1,
        output_dim = 8,
        input_length = 8
    )
)

model.add(LSTM(10))
model.add(Dense(1, activation = 'sigmoid'))

# %% [markdown]
# ## Compiling the model

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# ## Training the model

# %%
model.fit(
    encoded,
    labels,
    epochs = 10,
    verbose = 1,
    validation_split = 0.2
)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2500 - loss: 0.6954 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2500 - loss: 0.6938 - val_accuracy: 0.0000e+00 - val_loss: 0.6952
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7500 - loss: 0.6922 - val_accuracy: 0.0000e+00 - val_loss: 0.6978
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7500 - loss: 0.6906 - val_accuracy: 0.0000e+00 - val_loss: 0.7003
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7500 - loss: 0.6891 - val_accuracy: 0.0000e+00 - val_loss: 0.7029
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7500 - loss: 0.6875 - val_accuracy: 0.0000e+00 - val_loss: 0.7055
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.6859 - val_accuracy: 0.0000e+00 - val_loss: 0.7081
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.6843 - val_accuracy: 0.0000e+00 - val_loss: 0.7108
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7500 - loss: 0.6827 - val_accuracy: 0.0000e+00 - val_loss: 0.7135
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7500 - loss: 0.6811 - val_accuracy: 0.0000e+00 - val_loss: 0.7162
