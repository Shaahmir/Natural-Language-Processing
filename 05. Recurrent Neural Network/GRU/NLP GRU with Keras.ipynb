# %% [markdown]
# # LSTM with Keras

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Creating documents with labels

# %%
documents = [
    "Deep learning uses neural networks.",
    "LSTMs are powerful sequence models.",
    "I enjoy studying machine learning.",
    "Deep learning is truly amazing.",
    "Natural language processing is fascinating.",
    "Poorly trained models produce inaccurate results.",
]

# %%
labels = np.array([1, 1, 1, 0, 0, 0])

# %%
documents, labels
# Out:
# (['Deep learning uses neural networks.',
#   'LSTMs are powerful sequence models.',
#   'I enjoy studying machine learning.',
#   'Deep learning is truly amazing.',
#   'Natural language processing is fascinating.',
#   'Poorly trained models produce inaccurate results.'],
#  array([1, 1, 1, 0, 0, 0]))

# %% [markdown]
# ## Initializing TextVectorization

# %%
from tensorflow.keras.layers import TextVectorization

# %%
vectorizer = TextVectorization(
    max_tokens = 15000,
    standardize = 'lower_and_strip_punctuation',
    split = 'whitespace',
    output_mode = 'int',
    output_sequence_length = 8
)

# %%
vectorizer.adapt(documents)

# %%
encoded = vectorizer(documents)

# %% [markdown]
# ## Creating a GRU Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

# %%
model = Sequential()

model.add(
    Embedding(
        input_dim = len(vectorizer.get_vocabulary()) + 1,
        output_dim = 8,
        input_length = 8
    )
)

model.add(GRU(10))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %% [markdown]
# ## Compiling the model

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# ## Training the model

# %%
model.fit(
    encoded,
    labels,
    epochs = 10,
    verbose = 1,
    validation_split = 0.2
)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.2500 - loss: 0.6983 - val_accuracy: 1.0000 - val_loss: 0.6903
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.2500 - loss: 0.6953 - val_accuracy: 0.0000e+00 - val_loss: 0.6956
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7500 - loss: 0.6924 - val_accuracy: 0.0000e+00 - val_loss: 0.7009
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7500 - loss: 0.6896 - val_accuracy: 0.0000e+00 - val_loss: 0.7062
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.7500 - loss: 0.6868 - val_accuracy: 0.0000e+00 - val_loss: 0.7116
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7500 - loss: 0.6840 - val_accuracy: 0.0000e+00 - val_loss: 0.7170
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7500 - loss: 0.6812 - val_accuracy: 0.0000e+00 - val_loss: 0.7224
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7500 - loss: 0.6785 - val_accuracy: 0.0000e+00 - val_loss: 0.7279
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7500 - loss: 0.6758 - val_accuracy: 0.0000e+00 - val_loss: 0.7335
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7500 - loss: 0.6730 - val_accuracy: 0.0000e+00 - val_loss: 0.7391
