# %% [markdown]
# # Implementing TextBlob

# %% [markdown]
# ## Importing the library

# %%
from textblob import TextBlob
import nltk
nltk.download('brown')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Creating a TextBlob

# %%
wikipedia = TextBlob("Python is a high-level, general-purpose programming language used for a wide range of applications.")

# %%
print(wikipedia)
# Out:
# Python is a high-level, general-purpose programming language used for a wide range of applications.

# %% [markdown]
# ## Parts of Speech Taggings

# %% [markdown]
# **Each POS tag represents the grammatical role of the word in the sentence. Here’s the full form of each tag from your list:**
#
# <br>
#
# *   `NNP`: &nbsp; Proper Noun, Singular (e.g., "Python")
#
# *   `VBZ`: &nbsp; Verb, 3rd person singular present (e.g., "is")
#
# *   `DT`: &nbsp; Determiner (e.g., "a")
#
# *   `JJ`: &nbsp; Adjective (e.g., "high-level", "general-purpose")
#
# *   `NN`: &nbsp; Noun, Singular or Mass (e.g., "programming," "language")

# %%
wikipedia.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN'),
#  ('used', 'VBN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('wide', 'JJ'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('applications', 'NNS')]

# %% [markdown]
# # Noun Phrase Extraction
# Similarly, noun phrases are accessed through the noun_phrases property

# %%
wikipedia.noun_phrases
# Out:
# WordList(['python', 'wide range'])

# %% [markdown]
# ## Sentiment Analysis

# %%
testimonial = TextBlob("TextBlob is easy to use and offers a highly intuitive experience.")

if testimonial.sentiment[0] >= 0.1:
    print("Positive")
else:
    print("Negative")
# Out:
# Positive

# %%
testimonial = TextBlob("I dislike starting with complex concepts when learning something new.")

if testimonial.sentiment[0] >= 0.1:
    print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %% [markdown]
# ## Tokenization

# %%
documents = TextBlob(
    "Beautiful is better than ugly; "
    "explicit is better than implicit; "
    "simple is better than complex."
)

# %% [markdown]
# ### Word Based

# %%
documents.words
# Out:
# WordList(['Beautiful', 'is', 'better', 'than', 'ugly', 'explicit', 'is', 'better', 'than', 'implicit', 'simple', 'is', 'better', 'than', 'complex'])

# %% [markdown]
# ### Sentence Based

# %%
documents.sentences
# Out:
# [Sentence("Beautiful is better than ugly; explicit is better than implicit; simple is better than complex.")]

# %% [markdown]
# ## Words Inflection

# %%
sentence = TextBlob("Use 4 spaces per indentation level.")
sentence.words
# Out:
# WordList(['Use', '4', 'spaces', 'per', 'indentation', 'level'])

# %%
sentence.words[2].singularize()
# Out:
# 'space'

# %%
sentence.words[-1].pluralize()
# Out:
# 'levels'

# %% [markdown]
# ## Words Lemmatization

# %%
from textblob import Word
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
w = Word("places")
w.lemmatize('n')
# Out:
# 'place'

# %%
w = Word("went")
w.lemmatize("v")
# Out:
# 'go'

# %%
w = Word("loving")
w.lemmatize("v")
# Out:
# 'love'

# %% [markdown]
# ## Wordnet Integration

# %%
from textblob import Word
from textblob.wordnet import VERB

# %%
word = Word("places")
print(word.synsets[0].definition())
print(word.synsets[0].examples())
print(word.synsets[0].lemmas())
# Out:
# a point located with respect to surface features of some region
# ['this is a nice place for a picnic', 'a bright spot on a planet']
# [Lemma('topographic_point.n.01.topographic_point'), Lemma('topographic_point.n.01.place'), Lemma('topographic_point.n.01.spot')]

# %%
print(Word("place").get_synsets(pos = VERB))
# Out:
# [Synset('put.v.01'), Synset('place.v.02'), Synset('rate.v.01'), Synset('locate.v.03'), Synset('place.v.05'), Synset('place.v.06'), Synset('target.v.01'), Synset('identify.v.01'), Synset('place.v.09'), Synset('set.v.09'), Synset('place.v.11'), Synset('place.v.12'), Synset('invest.v.01'), Synset('station.v.01'), Synset('place.v.15'), Synset('place.v.16')]

# %%
print(Word("Place").definitions[:5])
# Out:
# ['a point located with respect to surface features of some region', 'any area set aside for a particular purpose', 'an abstract mental location', 'a general vicinity', 'the post or function properly or customarily occupied or served by another']

# %% [markdown]
# ## Spelling Correction

# %%
b = TextBlob("I knw howw to writee!")
print(b.correct())
# Out:
# I know how to write!

# %%
w = Word("noice")
w.spellcheck()
# Out:
# [('voice', 0.7085889570552147),
#  ('notice', 0.15030674846625766),
#  ('nice', 0.08128834355828221),
#  ('noise', 0.05828220858895705),
#  ('novice', 0.0015337423312883436)]

# %% [markdown]
# ## Text Parsing

# %% [markdown]
# **Word**: The actual word from the sentence.
#
# **POS-tag**: Part-of-speech tag, indicating the grammatical role of the word (e.g., "CC" for coordinating conjunction, "RB" for adverb, etc.).
#
# **Chunk-tag**: Indicates the beginning or continuation of a chunk (e.g., noun phrases, prepositional phrases). This uses B (beginning) and I (inside) tags to show chunk boundaries:
#
# <br>
#
# *  `B-NP`: Beginning of a noun phrase
#
# *  `I-NP`: Inside a noun phrase
#
# *  `B-PP`: Beginning of a prepositional phrase
#
# *  `B-ADVP`: Beginning of an adverbial phrase
#
# *  `O`: Outside of any chunk
#
# <br>
#
# Named-entity-tag: Marks named entities (e.g., organizations, locations) with specific tags. In your example, everything is tagged as O (Outside any named entity), meaning there are no named entities in this sentence.

# %%
b = TextBlob("And now for something entirely different.")
print(b.parse())
# Out:
# And/CC/O/O now/RB/B-ADVP/O for/IN/B-PP/B-PNP something/NN/B-NP/I-PNP entirely/RB/B-ADJP/O different/JJ/I-ADJP/O ././O/O

# %% [markdown]
# ## N-Gram (Uni-Gram, Bi-Gram, Tri-Gram)

# %%
blob = TextBlob("Better late than never.")

# %%
blob.ngrams(n = 1)
# Out:
# [WordList(['Better']),
#  WordList(['late']),
#  WordList(['than']),
#  WordList(['never'])]

# %%
blob.ngrams(n = 2)
# Out:
# [WordList(['Better', 'late']),
#  WordList(['late', 'than']),
#  WordList(['than', 'never'])]

# %%
blob.ngrams(n = 3)
# Out:
# [WordList(['Better', 'late', 'than']), WordList(['late', 'than', 'never'])]
